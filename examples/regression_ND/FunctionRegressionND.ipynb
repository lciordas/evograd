# %% [markdown]
# # N-Dimensional Function Regression with NEAT
#
# This notebook demonstrates using NEAT to approximate N-dimensional functions, from 2D to higher dimensions.

# %%
from matplotlib import pyplot as plt
import autograd.numpy as np
import random  
import sys
import os

# Add src directory to path (where 'evograd' package is located)
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
root_dir = os.path.abspath(os.path.join(notebook_dir, '../..'))
src_dir = os.path.join(root_dir, 'src')
regression_ND_dir = os.path.dirname(os.path.abspath('__file__'))  # Current regression_ND directory
sys.path.insert(0, src_dir)
sys.path.insert(0, regression_ND_dir)

from evograd.activations        import sigmoid_activation
from evograd.run                import Config
from trial_regressionND_grad import Trial_RegressionNDGrad, Experiment_RegressionNDGrad

# %%
# LOAD CONFIGURATION DATA
config = Config("config_regressionND.ini")
config.fitness_threshold      = 9.99   # maximum fitness is 10.0
config.population_size        = 10
config.gradient_steps         = 100
config.max_number_generations = 300
config.enable_gradient        = True
config.lamarckian_evolution   = True

# %%
# Define the function we want to approximate.
def foo2D(Z):
    (x,y) = Z
    x1 = sigmoid_activation(x)
    y1 = sigmoid_activation(y)
    return sigmoid_activation(x1 + y1)

# Define bounds for 2D problem
bounds_2d = [(-1.0, 0.5), 
             (-1.0, 0.5)]

# %%
if True:
    random.seed(27)      
    np.random.seed(27)   

trial = Trial_RegressionNDGrad(config, foo2D, bounds_2d, num_points=400, sampling='grid')
trial.run(num_jobs=-1)   # parallelize
# Out:
# ===============
# GENERATION 0000
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 7.2514
# Avg fitness improvement due to gradient descent: 2.776132
#
# Fittest Individual:
# ID=86, fitness=7.2514
# Nodes: [I0][I1][O2,SIG,b=0.19,g=-0.05]
# Conns: [000,E,01=>02,+0.00]
#
# ===============
# GENERATION 0001
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 8.0406
# Avg fitness improvement due to gradient descent: 1.836956
#
# Fittest Individual:
# ID=95, fitness=8.0406
# Nodes: [I0][I1][O2,SIG,b=0.27,g=-0.05]
# Conns: [000,E,01=>02,-0.44][001,E,00=>02,-4.39]
#
# ===============
# GENERATION 0002
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.1669
# Avg fitness improvement due to gradient descent: 2.200354
#
# Fittest Individual:
# ID=108, fitness=9.1669
# Nodes: [I0][I1][H5,SIG,b=0.47,g=1.76][O2,SIG,b=0.13,g=-0.10]
# Conns: [000,E,01=>02,-1.28][006,E,00=>05,+1.20][007,E,05=>02,-3.88]
#
# ===============
# GENERATION 0003
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.5316
# Avg fitness improvement due to gradient descent: 0.898899
#
# Fittest Individual:
# ID=108, fitness=9.5316
# Nodes: [I0][I1][H5,SIG,b=0.25,g=1.67][O2,SIG,b=0.18,g=-0.16]
# Conns: [000,E,01=>02,-1.43][006,E,00=>05,+1.11][007,E,05=>02,-3.41]
#
# ===============
# GENERATION 0004
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.5434
# Avg fitness improvement due to gradient descent: 2.077317
#
# Fittest Individual:
# ID=108, fitness=9.5434
# Nodes: [I0][I1][H5,SIG,b=0.13,g=1.42][O2,SIG,b=0.18,g=-0.16]
# Conns: [000,E,01=>02,-1.46][006,E,00=>05,+0.86][007,E,05=>02,-3.25]
#
# ===============
# GENERATION 0005
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.5441
# Avg fitness improvement due to gradient descent: 1.257635
#
# Fittest Individual:
# ID=108, fitness=9.5441
# Nodes: [I0][I1][H5,SIG,b=0.10,g=1.39][O2,SIG,b=0.18,g=-0.17]
# Conns: [000,E,01=>02,-1.39][006,E,00=>05,+0.83][007,E,05=>02,-3.58]
#
# ===============
# GENERATION 0006
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.6164
# Avg fitness improvement due to gradient descent: 2.503324
#
# Fittest Individual:
# ID=145, fitness=9.6164
# Nodes: [I0][I1][H5,SIG,b=0.04,g=1.70][H3,SIG,b=0.07,g=1.44][O2,SIG,b=0.04,g=-0.16]
# Conns: [006,E,00=>05,+1.11][007,E,05=>02,-20.91][002,E,01=>03,+1.94][003,E,03=>02,-2.86]
#
# ===============
# GENERATION 0007
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.9890
# Avg fitness improvement due to gradient descent: 1.758324
#
# Fittest Individual:
# ID=145, fitness=9.9890
# Nodes: [I0][I1][H5,SIG,b=-0.16,g=1.29][H3,SIG,b=0.22,g=1.08][O2,SIG,b=0.00,g=-0.18]
# Conns: [006,E,00=>05,+0.69][007,E,05=>02,-20.64][002,E,01=>03,+1.58][003,E,03=>02,-2.87]
#
# ===============
# GENERATION 0008
# Dimensions      = 2
# Sample points   = 400 (grid sampling)
# population size = 10
# number species  = 1
# maximum fitness = 9.9992
# Avg fitness improvement due to gradient descent: 1.362039
#
# Fittest Individual:
# ID=145, fitness=9.9992
# Nodes: [I0][I1][H5,SIG,b=-0.17,g=1.30][H3,SIG,b=0.09,g=0.84][O2,SIG,b=0.00,g=-0.20]
# Conns: [006,E,00=>05,+0.70][007,E,05=>02,-20.62][002,E,01=>03,+1.35][003,E,03=>02,-2.97]
#
#
# ==================================================
# GRADIENT DESCENT SUMMARY
# ==================================================
# Problem dimensionality:        2D
# Total gradient steps applied:  10
# Average loss improvement:      0.034075
# Total loss improvement:        0.340746
# Average fitness improvement:   1.362039
# Total fitness improvement:     13.620385
#
# Final MSE: 0.000008
# Final Fitness: 9.9992
# Network visualization saved as 'Digraph.gv.pdf'
